# %%
import pandas as pd

csv = pd.read_csv("data/coligacoes_1994-2014.csv",sep=";")
csv.head()
# Out:
#     COD_GERAL   ANO  UF_CODIGO UF_SIGLA CARGO_DESCRICAO  CARGO_CODIGO  \
# 0  1994101011  1994         10       BR      PRESIDENTE             1
# 1  1994101012  1994         10       BR      PRESIDENTE             1
# 2  1994101101  1994         10       BR      PRESIDENTE             1
# 3  1994101100  1994         10       BR      PRESIDENTE             1
# 4  1994101102  1994         10       BR      PRESIDENTE             1
#
#       TIPO_LEGENDA                        COLIGACAO_NOME  COLIGACAO_CODIGO  \
# 0  PARTIDO ISOLADO                                   NaN              1011
# 1  PARTIDO ISOLADO                                   NaN              1012
# 2        COLIGACAO  FRENTE BRASIL POPULAR PELA CIDADANIA              1101
# 3        COLIGACAO           UNI�O, TRABALHO E PROGRESSO              1100
# 4        COLIGACAO             DESENVOLVIMENTO DO BRASIL              1102
#
#    MINIMO      COLIGACAO_COMPOSICAO COLIGACAO_COMPOSICAO TSE  N PARTIDOS  \
# ...

# %%
data = csv[csv["CARGO_CODIGO"]==1]

# %%
data
# Out:
#         COD_GERAL   ANO  UF_CODIGO UF_SIGLA CARGO_DESCRICAO  CARGO_CODIGO  \
# 0      1994101011  1994         10       BR      PRESIDENTE             1
# 1      1994101012  1994         10       BR      PRESIDENTE             1
# 2      1994101101  1994         10       BR      PRESIDENTE             1
# 3      1994101100  1994         10       BR      PRESIDENTE             1
# 4      1994101102  1994         10       BR      PRESIDENTE             1
# 5      1994101101  1994         10       BR      PRESIDENTE             1
# 6      1994101020  1994         10       BR      PRESIDENTE             1
# 7      1994101101  1994         10       BR      PRESIDENTE             1
# 8      1994101100  1994         10       BR      PRESIDENTE             1
# 9      1994101036  1994         10       BR      PRESIDENTE             1
# 10     1994101101  1994         10       BR      PRESIDENTE             1
# 11     1994101102  1994         10       BR      PRESIDENTE             1
# ...
