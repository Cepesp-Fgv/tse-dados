# %% [markdown]
# ```mysql
# alter table output_micro_candidato set location 's3://datascience2016/data/gzip/output/micro/2014/3/brancos';
#
# INSERT OVERWRITE TABLE output_micro_candidato SELECT
# ANO_ELEICAO,
# NUM_TURNO,
# DESCRICAO_ELEICAO,
# UF AS SIGLA_UE,
# NOME_UF AS DESCRICAO_UE,
# CODIGO_CARGO,
# DESCRICAO_CARGO,
# "Voto Branco" AS NOME_CANDIDATO,
# "#BRANCO#" AS SEQUENCIAL_CANDIDATO,
# NUM_VOTAVEL AS NUMERO_CANDIDATO,
# "#BRANCO#" AS CPF_CANDIDATO,
# "#BRANCO#" AS NOME_URNA_CANDIDATO,
# "-1" AS COD_SITUACAO_CANDIDATURA,
# "-" AS DES_SITUACAO_CANDIDATURA,
# NUM_VOTAVEL AS NUMERO_PARTIDO,
# "#BRANCO#" AS SIGLA_PARTIDO,
# "#BRANCO#" AS NOME_PARTIDO,
# "#BRANCO#" AS CODIGO_LEGENDA,
# "#BRANCO#" AS SIGLA_LEGENDA,
# "#BRANCO#" AS COMPOSICAO_LEGENDA,
# "#BRANCO#" AS NOME_LEGENDA,
# "-1" AS CODIGO_OCUPACAO,
# "#BRANCO#" AS DESCRICAO_OCUPACAO,
# "" AS DATA_NASCIMENTO,
# "#BRANCO#" AS NUM_TITULO_ELEITORAL_CANDIDATO,
# "-1" AS IDADE_DATA_ELEICAO,
# "-1" AS CODIGO_SEXO,
# "-" AS DESCRICAO_SEXO,
# "-1" AS COD_GRAU_INSTRUCAO,
# "-" AS DESCRICAO_GRAU_INSTRUCAO,
# "-1" AS CODIGO_ESTADO_CIVIL,
# "-" AS DESCRICAO_ESTADO_CIVIL,
# "-1" AS CODIGO_COR_RACA,
# "-" AS DESCRICAO_COR_RACA,
# "-1" AS CODIGO_NACIONALIDADE,
# "-" AS DESCRICAO_NACIONALIDADE,
# "-" AS SIGLA_UF_NASCIMENTO,
# "-1" AS CODIGO_MUNICIPIO_NASCIMENTO,
# "-" AS NOME_MUNICIPIO_NASCIMENTO,
# "-1" AS DESPESA_MAX_CAMPANHA,
# "-1" AS COD_SIT_TOT_TURNO,
# "-" AS DESC_SIT_TOT_TURNO,
# "-" AS NM_EMAIL,
# "-" AS TIPO_LEGENDA,
# "-" AS SIGLA_COLIGACAO,
# "-" AS NOME_COLIGACAO,
# "-" AS COMPOSICAO_COLIGACAO,
# "-1" AS SEQUENCIA_COLIGACAO,
# CODIGO_MACRO,
# NOME_MACRO,
# UF,
# NOME_UF,
# CODIGO_MESO,
# NOME_MESO,
# CODIGO_MICRO,
# NOME_MICRO,
# sum(cast(QTDE_VOTOS AS INT)) as QTDE_VOTOS from ( select v1.*,
#                 m.CODIGO_MACRO,
#                 m.NOME_MACRO,
#                 m.UF,
#                 m.NOME_UF,
#                 m.CODIGO_MESO,
#                 m.NOME_MESO,
#                 m.CODIGO_MICRO,
#                 m.NOME_MICRO
#                 from (
#                     select * from votacao_secao_2014 where CODIGO_CARGO="1" and NUM_VOTAVEL="95") as v1
#                 join aux_municipio as m on m.CODIGO_MUNICIPIO=v1.CODIGO_MUNICIPIO
#             ) as v_s_m
# group by
# ANO_ELEICAO,
# NUM_TURNO,
# DESCRICAO_ELEICAO,
# CODIGO_MACRO,
# NOME_MACRO,
# UF,
# NOME_UF,
# CODIGO_MESO,
# NOME_MESO,
# CODIGO_MICRO,
# NOME_MICRO,
# CODIGO_CARGO,
# DESCRICAO_CARGO,
# NUM_VOTAVEL
# order by NUM_VOTAVEL;
#
# alter table output_micro_candidato set location 's3://datascience2016/data/gzip/output/micro/2014/3/nulos';
#
# INSERT OVERWRITE TABLE output_micro_candidato SELECT
# ANO_ELEICAO,
# NUM_TURNO,
# DESCRICAO_ELEICAO,
# UF AS SIGLA_UE,
# NOME_UF AS DESCRICAO_UE,
# CODIGO_CARGO,
# DESCRICAO_CARGO,
# "Voto Nulo" AS NOME_CANDIDATO,
# "#NULO#" AS SEQUENCIAL_CANDIDATO,
# NUM_VOTAVEL AS NUMERO_CANDIDATO,
# "#NULO#" AS CPF_CANDIDATO,
# "#NULO#" AS NOME_URNA_CANDIDATO,
# "-1" AS COD_SITUACAO_CANDIDATURA,
# "-" AS DES_SITUACAO_CANDIDATURA,
# NUM_VOTAVEL AS NUMERO_PARTIDO,
# "#NULO#" AS SIGLA_PARTIDO,
# "#NULO#" AS NOME_PARTIDO,
# "#NULO#" AS CODIGO_LEGENDA,
# "#NULO#" AS SIGLA_LEGENDA,
# "#NULO#" AS COMPOSICAO_LEGENDA,
# "#NULO#" AS NOME_LEGENDA,
# "-1" AS CODIGO_OCUPACAO,
# "#NULO#" AS DESCRICAO_OCUPACAO,
# "" AS DATA_NASCIMENTO,
# "#NULO#" AS NUM_TITULO_ELEITORAL_CANDIDATO,
# "-1" AS IDADE_DATA_ELEICAO,
# "-1" AS CODIGO_SEXO,
# "-" AS DESCRICAO_SEXO,
# "-1" AS COD_GRAU_INSTRUCAO,
# "-" AS DESCRICAO_GRAU_INSTRUCAO,
# "-1" AS CODIGO_ESTADO_CIVIL,
# "-" AS DESCRICAO_ESTADO_CIVIL,
# "-1" AS CODIGO_COR_RACA,
# "-" AS DESCRICAO_COR_RACA,
# "-1" AS CODIGO_NACIONALIDADE,
# "-" AS DESCRICAO_NACIONALIDADE,
# "-" AS SIGLA_UF_NASCIMENTO,
# "-1" AS CODIGO_MUNICIPIO_NASCIMENTO,
# "-" AS NOME_MUNICIPIO_NASCIMENTO,
# "-1" AS DESPESA_MAX_CAMPANHA,
# "-1" AS COD_SIT_TOT_TURNO,
# "-" AS DESC_SIT_TOT_TURNO,
# "-" AS NM_EMAIL,
# "-" AS TIPO_LEGENDA,
# "-" AS SIGLA_COLIGACAO,
# "-" AS NOME_COLIGACAO,
# "-" AS COMPOSICAO_COLIGACAO,
# "-1" AS SEQUENCIA_COLIGACAO,
# CODIGO_MACRO,
# NOME_MACRO,
# UF,
# NOME_UF,
# CODIGO_MESO,
# NOME_MESO,
# CODIGO_MICRO,
# NOME_MICRO,
# sum(cast(QTDE_VOTOS AS INT)) as QTDE_VOTOS from ( select v1.*,
#                 m.CODIGO_MACRO,
#                 m.NOME_MACRO,
#                 m.UF,
#                 m.NOME_UF,
#                 m.CODIGO_MESO,
#                 m.NOME_MESO,
#                 m.CODIGO_MICRO,
#                 m.NOME_MICRO
#                 from (
#                     select * from votacao_secao_2014 where CODIGO_CARGO="3" and (NUM_VOTAVEL="96" or NUM_VOTAVEL="97")) as v1
#                 join aux_municipio as m on m.CODIGO_MUNICIPIO=v1.CODIGO_MUNICIPIO
#             ) as v_s_m
# group by
# ANO_ELEICAO,
# NUM_TURNO,
# DESCRICAO_ELEICAO,
# CODIGO_MACRO,
# NOME_MACRO,
# UF,
# NOME_UF,
# CODIGO_MESO,
# NOME_MESO,
# CODIGO_MICRO,
# NOME_MICRO,
# CODIGO_CARGO,
# DESCRICAO_CARGO,
# NUM_VOTAVEL
# order by NUM_VOTAVEL;
#
# alter table output_micro_candidato set location 's3://datascience2016/data/gzip/output/micro/2014/5/brancos';
#
# INSERT OVERWRITE TABLE output_micro_candidato SELECT
# ANO_ELEICAO,
# NUM_TURNO,
# DESCRICAO_ELEICAO,
# UF AS SIGLA_UE,
# NOME_UF AS DESCRICAO_UE,
# CODIGO_CARGO,
# DESCRICAO_CARGO,
# "Voto Branco" AS NOME_CANDIDATO,
# "#BRANCO#" AS SEQUENCIAL_CANDIDATO,
# NUM_VOTAVEL AS NUMERO_CANDIDATO,
# "#BRANCO#" AS CPF_CANDIDATO,
# "#BRANCO#" AS NOME_URNA_CANDIDATO,
# "-1" AS COD_SITUACAO_CANDIDATURA,
# "-" AS DES_SITUACAO_CANDIDATURA,
# NUM_VOTAVEL AS NUMERO_PARTIDO,
# "#BRANCO#" AS SIGLA_PARTIDO,
# "#BRANCO#" AS NOME_PARTIDO,
# "#BRANCO#" AS CODIGO_LEGENDA,
# "#BRANCO#" AS SIGLA_LEGENDA,
# "#BRANCO#" AS COMPOSICAO_LEGENDA,
# "#BRANCO#" AS NOME_LEGENDA,
# "-1" AS CODIGO_OCUPACAO,
# "#BRANCO#" AS DESCRICAO_OCUPACAO,
# "" AS DATA_NASCIMENTO,
# "#BRANCO#" AS NUM_TITULO_ELEITORAL_CANDIDATO,
# "-1" AS IDADE_DATA_ELEICAO,
# "-1" AS CODIGO_SEXO,
# "-" AS DESCRICAO_SEXO,
# "-1" AS COD_GRAU_INSTRUCAO,
# "-" AS DESCRICAO_GRAU_INSTRUCAO,
# "-1" AS CODIGO_ESTADO_CIVIL,
# "-" AS DESCRICAO_ESTADO_CIVIL,
# "-1" AS CODIGO_COR_RACA,
# "-" AS DESCRICAO_COR_RACA,
# "-1" AS CODIGO_NACIONALIDADE,
# "-" AS DESCRICAO_NACIONALIDADE,
# "-" AS SIGLA_UF_NASCIMENTO,
# "-1" AS CODIGO_MUNICIPIO_NASCIMENTO,
# "-" AS NOME_MUNICIPIO_NASCIMENTO,
# "-1" AS DESPESA_MAX_CAMPANHA,
# "-1" AS COD_SIT_TOT_TURNO,
# "-" AS DESC_SIT_TOT_TURNO,
# "-" AS NM_EMAIL,
# "-" AS TIPO_LEGENDA,
# "-" AS SIGLA_COLIGACAO,
# "-" AS NOME_COLIGACAO,
# "-" AS COMPOSICAO_COLIGACAO,
# "-1" AS SEQUENCIA_COLIGACAO,
# CODIGO_MACRO,
# NOME_MACRO,
# UF,
# NOME_UF,
# CODIGO_MESO,
# NOME_MESO,
# CODIGO_MICRO,
# NOME_MICRO,
# sum(cast(QTDE_VOTOS AS INT)) as QTDE_VOTOS from ( select v1.*,
#                 m.CODIGO_MACRO,
#                 m.NOME_MACRO,
#                 m.UF,
#                 m.NOME_UF,
#                 m.CODIGO_MESO,
#                 m.NOME_MESO,
#                 m.CODIGO_MICRO,
#                 m.NOME_MICRO
#                 from (
#                     select * from votacao_secao_2014 where CODIGO_CARGO="5" and NUM_VOTAVEL="95") as v1
#                 join aux_municipio as m on m.CODIGO_MUNICIPIO=v1.CODIGO_MUNICIPIO
#             ) as v_s_m
# group by
# ANO_ELEICAO,
# NUM_TURNO,
# DESCRICAO_ELEICAO,
# CODIGO_MACRO,
# NOME_MACRO,
# UF,
# NOME_UF,
# CODIGO_MESO,
# NOME_MESO,
# CODIGO_MICRO,
# NOME_MICRO,
# CODIGO_CARGO,
# DESCRICAO_CARGO,
# NUM_VOTAVEL
# order by NUM_VOTAVEL;
#
# alter table output_micro_candidato set location 's3://datascience2016/data/gzip/output/micro/2014/5/nulos';
#
# INSERT OVERWRITE TABLE output_micro_candidato SELECT
# ANO_ELEICAO,
# NUM_TURNO,
# DESCRICAO_ELEICAO,
# UF AS SIGLA_UE,
# NOME_UF AS DESCRICAO_UE,
# CODIGO_CARGO,
# DESCRICAO_CARGO,
# "Voto Nulo" AS NOME_CANDIDATO,
# "#NULO#" AS SEQUENCIAL_CANDIDATO,
# NUM_VOTAVEL AS NUMERO_CANDIDATO,
# "#NULO#" AS CPF_CANDIDATO,
# "#NULO#" AS NOME_URNA_CANDIDATO,
# "-1" AS COD_SITUACAO_CANDIDATURA,
# "-" AS DES_SITUACAO_CANDIDATURA,
# NUM_VOTAVEL AS NUMERO_PARTIDO,
# "#NULO#" AS SIGLA_PARTIDO,
# "#NULO#" AS NOME_PARTIDO,
# "#NULO#" AS CODIGO_LEGENDA,
# "#NULO#" AS SIGLA_LEGENDA,
# "#NULO#" AS COMPOSICAO_LEGENDA,
# "#NULO#" AS NOME_LEGENDA,
# "-1" AS CODIGO_OCUPACAO,
# "#NULO#" AS DESCRICAO_OCUPACAO,
# "" AS DATA_NASCIMENTO,
# "#NULO#" AS NUM_TITULO_ELEITORAL_CANDIDATO,
# "-1" AS IDADE_DATA_ELEICAO,
# "-1" AS CODIGO_SEXO,
# "-" AS DESCRICAO_SEXO,
# "-1" AS COD_GRAU_INSTRUCAO,
# "-" AS DESCRICAO_GRAU_INSTRUCAO,
# "-1" AS CODIGO_ESTADO_CIVIL,
# "-" AS DESCRICAO_ESTADO_CIVIL,
# "-1" AS CODIGO_COR_RACA,
# "-" AS DESCRICAO_COR_RACA,
# "-1" AS CODIGO_NACIONALIDADE,
# "-" AS DESCRICAO_NACIONALIDADE,
# "-" AS SIGLA_UF_NASCIMENTO,
# "-1" AS CODIGO_MUNICIPIO_NASCIMENTO,
# "-" AS NOME_MUNICIPIO_NASCIMENTO,
# "-1" AS DESPESA_MAX_CAMPANHA,
# "-1" AS COD_SIT_TOT_TURNO,
# "-" AS DESC_SIT_TOT_TURNO,
# "-" AS NM_EMAIL,
# "-" AS TIPO_LEGENDA,
# "-" AS SIGLA_COLIGACAO,
# "-" AS NOME_COLIGACAO,
# "-" AS COMPOSICAO_COLIGACAO,
# "-1" AS SEQUENCIA_COLIGACAO,
# CODIGO_MACRO,
# NOME_MACRO,
# UF,
# NOME_UF,
# CODIGO_MESO,
# NOME_MESO,
# CODIGO_MICRO,
# NOME_MICRO,
# sum(cast(QTDE_VOTOS AS INT)) as QTDE_VOTOS from ( select v1.*,
#                 m.CODIGO_MACRO,
#                 m.NOME_MACRO,
#                 m.UF,
#                 m.NOME_UF,
#                 m.CODIGO_MESO,
#                 m.NOME_MESO,
#                 m.CODIGO_MICRO,
#                 m.NOME_MICRO
#                 from (
#                     select * from votacao_secao_2014 where CODIGO_CARGO="5" and (NUM_VOTAVEL="96" or NUM_VOTAVEL="97")) as v1
#                 join aux_municipio as m on m.CODIGO_MUNICIPIO=v1.CODIGO_MUNICIPIO
#             ) as v_s_m
# group by
# ANO_ELEICAO,
# NUM_TURNO,
# DESCRICAO_ELEICAO,
# CODIGO_MACRO,
# NOME_MACRO,
# UF,
# NOME_UF,
# CODIGO_MESO,
# NOME_MESO,
# CODIGO_MICRO,
# NOME_MICRO,
# CODIGO_CARGO,
# DESCRICAO_CARGO,
# NUM_VOTAVEL
# order by NUM_VOTAVEL;
#
# alter table output_micro_candidato set location 's3://datascience2016/data/gzip/output/micro/2014/6/brancos';
#
# INSERT OVERWRITE TABLE output_micro_candidato SELECT
# ANO_ELEICAO,
# NUM_TURNO,
# DESCRICAO_ELEICAO,
# UF AS SIGLA_UE,
# NOME_UF AS DESCRICAO_UE,
# CODIGO_CARGO,
# DESCRICAO_CARGO,
# "Voto Branco" AS NOME_CANDIDATO,
# "#BRANCO#" AS SEQUENCIAL_CANDIDATO,
# NUM_VOTAVEL AS NUMERO_CANDIDATO,
# "#BRANCO#" AS CPF_CANDIDATO,
# "#BRANCO#" AS NOME_URNA_CANDIDATO,
# "-1" AS COD_SITUACAO_CANDIDATURA,
# "-" AS DES_SITUACAO_CANDIDATURA,
# NUM_VOTAVEL AS NUMERO_PARTIDO,
# "#BRANCO#" AS SIGLA_PARTIDO,
# "#BRANCO#" AS NOME_PARTIDO,
# "#BRANCO#" AS CODIGO_LEGENDA,
# "#BRANCO#" AS SIGLA_LEGENDA,
# "#BRANCO#" AS COMPOSICAO_LEGENDA,
# "#BRANCO#" AS NOME_LEGENDA,
# "-1" AS CODIGO_OCUPACAO,
# "#BRANCO#" AS DESCRICAO_OCUPACAO,
# "" AS DATA_NASCIMENTO,
# "#BRANCO#" AS NUM_TITULO_ELEITORAL_CANDIDATO,
# "-1" AS IDADE_DATA_ELEICAO,
# "-1" AS CODIGO_SEXO,
# "-" AS DESCRICAO_SEXO,
# "-1" AS COD_GRAU_INSTRUCAO,
# "-" AS DESCRICAO_GRAU_INSTRUCAO,
# "-1" AS CODIGO_ESTADO_CIVIL,
# "-" AS DESCRICAO_ESTADO_CIVIL,
# "-1" AS CODIGO_COR_RACA,
# "-" AS DESCRICAO_COR_RACA,
# "-1" AS CODIGO_NACIONALIDADE,
# "-" AS DESCRICAO_NACIONALIDADE,
# "-" AS SIGLA_UF_NASCIMENTO,
# "-1" AS CODIGO_MUNICIPIO_NASCIMENTO,
# "-" AS NOME_MUNICIPIO_NASCIMENTO,
# "-1" AS DESPESA_MAX_CAMPANHA,
# "-1" AS COD_SIT_TOT_TURNO,
# "-" AS DESC_SIT_TOT_TURNO,
# "-" AS NM_EMAIL,
# "-" AS TIPO_LEGENDA,
# "-" AS SIGLA_COLIGACAO,
# "-" AS NOME_COLIGACAO,
# "-" AS COMPOSICAO_COLIGACAO,
# "-1" AS SEQUENCIA_COLIGACAO,
# CODIGO_MACRO,
# NOME_MACRO,
# UF,
# NOME_UF,
# CODIGO_MESO,
# NOME_MESO,
# CODIGO_MICRO,
# NOME_MICRO,
# sum(cast(QTDE_VOTOS AS INT)) as QTDE_VOTOS from ( select v1.*,
#                 m.CODIGO_MACRO,
#                 m.NOME_MACRO,
#                 m.UF,
#                 m.NOME_UF,
#                 m.CODIGO_MESO,
#                 m.NOME_MESO,
#                 m.CODIGO_MICRO,
#                 m.NOME_MICRO
#                 from (
#                     select * from votacao_secao_2014 where CODIGO_CARGO="6" and NUM_VOTAVEL="95") as v1
#                 join aux_municipio as m on m.CODIGO_MUNICIPIO=v1.CODIGO_MUNICIPIO
#             ) as v_s_m
# group by
# ANO_ELEICAO,
# NUM_TURNO,
# DESCRICAO_ELEICAO,
# CODIGO_MACRO,
# NOME_MACRO,
# UF,
# NOME_UF,
# CODIGO_MESO,
# NOME_MESO,
# CODIGO_MICRO,
# NOME_MICRO,
# CODIGO_CARGO,
# DESCRICAO_CARGO,
# NUM_VOTAVEL
# order by NUM_VOTAVEL;
#
# alter table output_micro_candidato set location 's3://datascience2016/data/gzip/output/micro/2014/6/nulos';
#
# INSERT OVERWRITE TABLE output_micro_candidato SELECT
# ANO_ELEICAO,
# NUM_TURNO,
# DESCRICAO_ELEICAO,
# UF AS SIGLA_UE,
# NOME_UF AS DESCRICAO_UE,
# CODIGO_CARGO,
# DESCRICAO_CARGO,
# "Voto Nulo" AS NOME_CANDIDATO,
# "#NULO#" AS SEQUENCIAL_CANDIDATO,
# NUM_VOTAVEL AS NUMERO_CANDIDATO,
# "#NULO#" AS CPF_CANDIDATO,
# "#NULO#" AS NOME_URNA_CANDIDATO,
# "-1" AS COD_SITUACAO_CANDIDATURA,
# "-" AS DES_SITUACAO_CANDIDATURA,
# NUM_VOTAVEL AS NUMERO_PARTIDO,
# "#NULO#" AS SIGLA_PARTIDO,
# "#NULO#" AS NOME_PARTIDO,
# "#NULO#" AS CODIGO_LEGENDA,
# "#NULO#" AS SIGLA_LEGENDA,
# "#NULO#" AS COMPOSICAO_LEGENDA,
# "#NULO#" AS NOME_LEGENDA,
# "-1" AS CODIGO_OCUPACAO,
# "#NULO#" AS DESCRICAO_OCUPACAO,
# "" AS DATA_NASCIMENTO,
# "#NULO#" AS NUM_TITULO_ELEITORAL_CANDIDATO,
# "-1" AS IDADE_DATA_ELEICAO,
# "-1" AS CODIGO_SEXO,
# "-" AS DESCRICAO_SEXO,
# "-1" AS COD_GRAU_INSTRUCAO,
# "-" AS DESCRICAO_GRAU_INSTRUCAO,
# "-1" AS CODIGO_ESTADO_CIVIL,
# "-" AS DESCRICAO_ESTADO_CIVIL,
# "-1" AS CODIGO_COR_RACA,
# "-" AS DESCRICAO_COR_RACA,
# "-1" AS CODIGO_NACIONALIDADE,
# "-" AS DESCRICAO_NACIONALIDADE,
# "-" AS SIGLA_UF_NASCIMENTO,
# "-1" AS CODIGO_MUNICIPIO_NASCIMENTO,
# "-" AS NOME_MUNICIPIO_NASCIMENTO,
# "-1" AS DESPESA_MAX_CAMPANHA,
# "-1" AS COD_SIT_TOT_TURNO,
# "-" AS DESC_SIT_TOT_TURNO,
# "-" AS NM_EMAIL,
# "-" AS TIPO_LEGENDA,
# "-" AS SIGLA_COLIGACAO,
# "-" AS NOME_COLIGACAO,
# "-" AS COMPOSICAO_COLIGACAO,
# "-1" AS SEQUENCIA_COLIGACAO,
# CODIGO_MACRO,
# NOME_MACRO,
# UF,
# NOME_UF,
# CODIGO_MESO,
# NOME_MESO,
# CODIGO_MICRO,
# NOME_MICRO,
# sum(cast(QTDE_VOTOS AS INT)) as QTDE_VOTOS from ( select v1.*,
#                 m.CODIGO_MACRO,
#                 m.NOME_MACRO,
#                 m.UF,
#                 m.NOME_UF,
#                 m.CODIGO_MESO,
#                 m.NOME_MESO,
#                 m.CODIGO_MICRO,
#                 m.NOME_MICRO
#                 from (
#                     select * from votacao_secao_2014 where CODIGO_CARGO="6" and (NUM_VOTAVEL="96" or NUM_VOTAVEL="97")) as v1
#                 join aux_municipio as m on m.CODIGO_MUNICIPIO=v1.CODIGO_MUNICIPIO
#             ) as v_s_m
# group by
# ANO_ELEICAO,
# NUM_TURNO,
# DESCRICAO_ELEICAO,
# CODIGO_MACRO,
# NOME_MACRO,
# UF,
# NOME_UF,
# CODIGO_MESO,
# NOME_MESO,
# CODIGO_MICRO,
# NOME_MICRO,
# CODIGO_CARGO,
# DESCRICAO_CARGO,
# NUM_VOTAVEL
# order by NUM_VOTAVEL;
#
# alter table output_micro_candidato set location 's3://datascience2016/data/gzip/output/micro/2014/7/brancos';
#
# INSERT OVERWRITE TABLE output_micro_candidato SELECT
# ANO_ELEICAO,
# NUM_TURNO,
# DESCRICAO_ELEICAO,
# UF AS SIGLA_UE,
# NOME_UF AS DESCRICAO_UE,
# CODIGO_CARGO,
# DESCRICAO_CARGO,
# "Voto Branco" AS NOME_CANDIDATO,
# "#BRANCO#" AS SEQUENCIAL_CANDIDATO,
# NUM_VOTAVEL AS NUMERO_CANDIDATO,
# "#BRANCO#" AS CPF_CANDIDATO,
# "#BRANCO#" AS NOME_URNA_CANDIDATO,
# "-1" AS COD_SITUACAO_CANDIDATURA,
# "-" AS DES_SITUACAO_CANDIDATURA,
# NUM_VOTAVEL AS NUMERO_PARTIDO,
# "#BRANCO#" AS SIGLA_PARTIDO,
# "#BRANCO#" AS NOME_PARTIDO,
# "#BRANCO#" AS CODIGO_LEGENDA,
# "#BRANCO#" AS SIGLA_LEGENDA,
# "#BRANCO#" AS COMPOSICAO_LEGENDA,
# "#BRANCO#" AS NOME_LEGENDA,
# "-1" AS CODIGO_OCUPACAO,
# "#BRANCO#" AS DESCRICAO_OCUPACAO,
# "" AS DATA_NASCIMENTO,
# "#BRANCO#" AS NUM_TITULO_ELEITORAL_CANDIDATO,
# "-1" AS IDADE_DATA_ELEICAO,
# "-1" AS CODIGO_SEXO,
# "-" AS DESCRICAO_SEXO,
# "-1" AS COD_GRAU_INSTRUCAO,
# "-" AS DESCRICAO_GRAU_INSTRUCAO,
# "-1" AS CODIGO_ESTADO_CIVIL,
# "-" AS DESCRICAO_ESTADO_CIVIL,
# "-1" AS CODIGO_COR_RACA,
# "-" AS DESCRICAO_COR_RACA,
# "-1" AS CODIGO_NACIONALIDADE,
# "-" AS DESCRICAO_NACIONALIDADE,
# "-" AS SIGLA_UF_NASCIMENTO,
# "-1" AS CODIGO_MUNICIPIO_NASCIMENTO,
# "-" AS NOME_MUNICIPIO_NASCIMENTO,
# "-1" AS DESPESA_MAX_CAMPANHA,
# "-1" AS COD_SIT_TOT_TURNO,
# "-" AS DESC_SIT_TOT_TURNO,
# "-" AS NM_EMAIL,
# "-" AS TIPO_LEGENDA,
# "-" AS SIGLA_COLIGACAO,
# "-" AS NOME_COLIGACAO,
# "-" AS COMPOSICAO_COLIGACAO,
# "-1" AS SEQUENCIA_COLIGACAO,
# CODIGO_MACRO,
# NOME_MACRO,
# UF,
# NOME_UF,
# CODIGO_MESO,
# NOME_MESO,
# CODIGO_MICRO,
# NOME_MICRO,
# sum(cast(QTDE_VOTOS AS INT)) as QTDE_VOTOS from ( select v1.*,
#                 m.CODIGO_MACRO,
#                 m.NOME_MACRO,
#                 m.UF,
#                 m.NOME_UF,
#                 m.CODIGO_MESO,
#                 m.NOME_MESO,
#                 m.CODIGO_MICRO,
#                 m.NOME_MICRO
#                 from (
#                     select * from votacao_secao_2014 where CODIGO_CARGO="7" and NUM_VOTAVEL="95") as v1
#                 join aux_municipio as m on m.CODIGO_MUNICIPIO=v1.CODIGO_MUNICIPIO
#             ) as v_s_m
# group by
# ANO_ELEICAO,
# NUM_TURNO,
# DESCRICAO_ELEICAO,
# CODIGO_MACRO,
# NOME_MACRO,
# UF,
# NOME_UF,
# CODIGO_MESO,
# NOME_MESO,
# CODIGO_MICRO,
# NOME_MICRO,
# CODIGO_CARGO,
# DESCRICAO_CARGO,
# NUM_VOTAVEL
# order by NUM_VOTAVEL;
#
# alter table output_micro_candidato set location 's3://datascience2016/data/gzip/output/micro/2014/7/nulos';
#
# INSERT OVERWRITE TABLE output_micro_candidato SELECT
# ANO_ELEICAO,
# NUM_TURNO,
# DESCRICAO_ELEICAO,
# UF AS SIGLA_UE,
# NOME_UF AS DESCRICAO_UE,
# CODIGO_CARGO,
# DESCRICAO_CARGO,
# "Voto Nulo" AS NOME_CANDIDATO,
# "#NULO#" AS SEQUENCIAL_CANDIDATO,
# NUM_VOTAVEL AS NUMERO_CANDIDATO,
# "#NULO#" AS CPF_CANDIDATO,
# "#NULO#" AS NOME_URNA_CANDIDATO,
# "-1" AS COD_SITUACAO_CANDIDATURA,
# "-" AS DES_SITUACAO_CANDIDATURA,
# NUM_VOTAVEL AS NUMERO_PARTIDO,
# "#NULO#" AS SIGLA_PARTIDO,
# "#NULO#" AS NOME_PARTIDO,
# "#NULO#" AS CODIGO_LEGENDA,
# "#NULO#" AS SIGLA_LEGENDA,
# "#NULO#" AS COMPOSICAO_LEGENDA,
# "#NULO#" AS NOME_LEGENDA,
# "-1" AS CODIGO_OCUPACAO,
# "#NULO#" AS DESCRICAO_OCUPACAO,
# "" AS DATA_NASCIMENTO,
# "#NULO#" AS NUM_TITULO_ELEITORAL_CANDIDATO,
# "-1" AS IDADE_DATA_ELEICAO,
# "-1" AS CODIGO_SEXO,
# "-" AS DESCRICAO_SEXO,
# "-1" AS COD_GRAU_INSTRUCAO,
# "-" AS DESCRICAO_GRAU_INSTRUCAO,
# "-1" AS CODIGO_ESTADO_CIVIL,
# "-" AS DESCRICAO_ESTADO_CIVIL,
# "-1" AS CODIGO_COR_RACA,
# "-" AS DESCRICAO_COR_RACA,
# "-1" AS CODIGO_NACIONALIDADE,
# "-" AS DESCRICAO_NACIONALIDADE,
# "-" AS SIGLA_UF_NASCIMENTO,
# "-1" AS CODIGO_MUNICIPIO_NASCIMENTO,
# "-" AS NOME_MUNICIPIO_NASCIMENTO,
# "-1" AS DESPESA_MAX_CAMPANHA,
# "-1" AS COD_SIT_TOT_TURNO,
# "-" AS DESC_SIT_TOT_TURNO,
# "-" AS NM_EMAIL,
# "-" AS TIPO_LEGENDA,
# "-" AS SIGLA_COLIGACAO,
# "-" AS NOME_COLIGACAO,
# "-" AS COMPOSICAO_COLIGACAO,
# "-1" AS SEQUENCIA_COLIGACAO,
# CODIGO_MACRO,
# NOME_MACRO,
# UF,
# NOME_UF,
# CODIGO_MESO,
# NOME_MESO,
# CODIGO_MICRO,
# NOME_MICRO,
# sum(cast(QTDE_VOTOS AS INT)) as QTDE_VOTOS from ( select v1.*,
#                 m.CODIGO_MACRO,
#                 m.NOME_MACRO,
#                 m.UF,
#                 m.NOME_UF,
#                 m.CODIGO_MESO,
#                 m.NOME_MESO,
#                 m.CODIGO_MICRO,
#                 m.NOME_MICRO
#                 from (
#                     select * from votacao_secao_2014 where CODIGO_CARGO="7" and (NUM_VOTAVEL="96" or NUM_VOTAVEL="97")) as v1
#                 join aux_municipio as m on m.CODIGO_MUNICIPIO=v1.CODIGO_MUNICIPIO
#             ) as v_s_m
# group by
# ANO_ELEICAO,
# NUM_TURNO,
# DESCRICAO_ELEICAO,
# CODIGO_MACRO,
# NOME_MACRO,
# UF,
# NOME_UF,
# CODIGO_MESO,
# NOME_MESO,
# CODIGO_MICRO,
# NOME_MICRO,
# CODIGO_CARGO,
# DESCRICAO_CARGO,
# NUM_VOTAVEL
# order by NUM_VOTAVEL;
#
# ```

# %% [markdown]
# ## Votos Brancos

# %%
import pandas as pd
import csv

data = pd.read_csv("input/brancos.csv",delimiter="\t",error_bad_lines=False,names=["ANO_ELEICAO","NUM_TURNO","DESCRICAO_ELEICAO","SIGLA_UF","SIGLA_UE","CODIGO_CARGO","DESCRICAO_CARGO","NUMERO_CANDIDATO"])
data["DATA_GERACAO"]= ""
data["HORA_GERACAO"]= ""
data["NOME_CANDIDATO"]= "Voto Branco"
data["SEQUENCIAL_CANDIDATO"]= "#BRANCO#"
data["CPF_CANDIDATO"]= "#BRANCO#"
data["NOME_URNA_CANDIDATO"]= "Voto Branco"
data["COD_SITUACAO_CANDIDATURA"]= "-1"
data["DES_SITUACAO_CANDIDATURA"]= "-"
data["NUMERO_PARTIDO"]= "95"
data["SIGLA_PARTIDO"]= "#BRANCO#"
data["NOME_PARTIDO"]= "#BRANCO#"
data["CODIGO_LEGENDA"]= "#BRANCO#"
data["DESCRICAO_UE"]= data["SIGLA_UE"]
data["SIGLA_LEGENDA"]= "#BRANCO#"
data["COMPOSICAO_LEGENDA"]= "#BRANCO#"
data["NOME_LEGENDA"]= "#BRANCO#"
data["CODIGO_OCUPACAO"]= "-1"
data["DESCRICAO_OCUPACAO"]= "#BRANCO#"
data["DATA_NASCIMENTO"]= ""
data["NUM_TITULO_ELEITORAL_CANDIDATO"]= "#BRANCO#"
data["IDADE_DATA_ELEICAO"]= "-1"
data["CODIGO_SEXO"]= "-1"
data["DESCRICAO_SEXO"]= "-"
data["COD_GRAU_INSTRUCAO"]= "-1"
data["DESCRICAO_GRAU_INSTRUCAO"]= "-"
data["CODIGO_ESTADO_CIVIL"]= "-1"
data["DESCRICAO_ESTADO_CIVIL"]= "-"
data["CODIGO_COR_RACA"]= "-1"
data["DESCRICAO_COR_RACA"]= "-"
data["CODIGO_NACIONALIDADE"]= "-1"
data["DESCRICAO_NACIONALIDADE"]= "-"
data["SIGLA_UF_NASCIMENTO"]= "-"
data["CODIGO_MUNICIPIO_NASCIMENTO"]= "-"
data["NOME_MUNICIPIO_NASCIMENTO"]= "-"
data["DESPESA_MAX_CAMPANHA"]= "-"
data["COD_SIT_TOT_TURNO"]= "-"
data["DESC_SIT_TOT_TURNO"]= "-"
data["NM_EMAIL"]= "-"
data.reindex(columns=["DATA_GERACAO",
"HORA_GERACAO",
"ANO_ELEICAO",
"NUM_TURNO",
"DESCRICAO_ELEICAO",
"SIGLA_UF",
"SIGLA_UE",
"DESCRICAO_UE",
"CODIGO_CARGO",
"DESCRICAO_CARGO",
"NOME_CANDIDATO",
"SEQUENCIAL_CANDIDATO",
"NUMERO_CANDIDATO",
"CPF_CANDIDATO",
"NOME_URNA_CANDIDATO",
"COD_SITUACAO_CANDIDATURA",
"DES_SITUACAO_CANDIDATURA",
"NUMERO_PARTIDO",
"SIGLA_PARTIDO",
"NOME_PARTIDO",
"CODIGO_LEGENDA",
"SIGLA_LEGENDA",
"COMPOSICAO_LEGENDA",
"NOME_LEGENDA",
"CODIGO_OCUPACAO",
"DESCRICAO_OCUPACAO",
"DATA_NASCIMENTO",
"NUM_TITULO_ELEITORAL_CANDIDATO",
"IDADE_DATA_ELEICAO",
"CODIGO_SEXO",
"DESCRICAO_SEXO",
"COD_GRAU_INSTRUCAO",
"DESCRICAO_GRAU_INSTRUCAO",
"CODIGO_ESTADO_CIVIL",
"DESCRICAO_ESTADO_CIVIL",
"CODIGO_COR_RACA",
"DESCRICAO_COR_RACA",
"CODIGO_NACIONALIDADE",
"DESCRICAO_NACIONALIDADE",
"SIGLA_UF_NASCIMENTO",
"CODIGO_MUNICIPIO_NASCIMENTO",
"NOME_MUNICIPIO_NASCIMENTO",
"DESPESA_MAX_CAMPANHA",
"COD_SIT_TOT_TURNO",
"DESC_SIT_TOT_TURNO",
"NM_EMAIL"]).to_csv('output/brancos.txt',sep=';', encoding='utf-8',index=False,header=False, quoting=csv.QUOTE_ALL)

# %% [markdown]
# ## Votos Nulos

# %%
data = pd.read_csv("input/nulos.csv",delimiter="\t",error_bad_lines=False,names=["ANO_ELEICAO","NUM_TURNO","DESCRICAO_ELEICAO","SIGLA_UF","SIGLA_UE","CODIGO_MUNICIPIO","DESCRICAO_UE","CODIGO_CARGO","DESCRICAO_CARGO","NUMERO_CANDIDATO"])
data["DATA_GERACAO"]= ""
data["HORA_GERACAO"]= ""
data["NOME_CANDIDATO"]= "Voto Nulo"
data["SEQUENCIAL_CANDIDATO"]= "#NULO#"
data["CPF_CANDIDATO"]= "#NULO#"
data["NOME_URNA_CANDIDATO"]= "Voto Nulo"
data["COD_SITUACAO_CANDIDATURA"]= "-1"
data["DES_SITUACAO_CANDIDATURA"]= "-"
data["NUMERO_PARTIDO"]= "95"
data["SIGLA_PARTIDO"]= "#NULO#"
data["NOME_PARTIDO"]= "#NULO#"
data["CODIGO_LEGENDA"]= "#NULO#"
data["SIGLA_LEGENDA"]= "#NULO#"
data["COMPOSICAO_LEGENDA"]= "#NULO#"
data["NOME_LEGENDA"]= "#NULO#"
data["CODIGO_OCUPACAO"]= "-1"
data["DESCRICAO_OCUPACAO"]= "#NULO#"
data["DATA_NASCIMENTO"]= ""
data["NUM_TITULO_ELEITORAL_CANDIDATO"]= "#NULO#"
data["IDADE_DATA_ELEICAO"]= "-1"
data["CODIGO_SEXO"]= "-1"
data["DESCRICAO_SEXO"]= "-"
data["COD_GRAU_INSTRUCAO"]= "-1"
data["DESCRICAO_GRAU_INSTRUCAO"]= "-"
data["CODIGO_ESTADO_CIVIL"]= "-1"
data["DESCRICAO_ESTADO_CIVIL"]= "-"
data["CODIGO_COR_RACA"]= "-1"
data["DESCRICAO_COR_RACA"]= "-"
data["CODIGO_NACIONALIDADE"]= "-1"
data["DESCRICAO_NACIONALIDADE"]= "-"
data["SIGLA_UF_NASCIMENTO"]= "-"
data["CODIGO_MUNICIPIO_NASCIMENTO"]= "-"
data["NOME_MUNICIPIO_NASCIMENTO"]= "-"
data["DESPESA_MAX_CAMPANHA"]= "-"
data["COD_SIT_TOT_TURNO"]= "-"
data["DESC_SIT_TOT_TURNO"]= "-"
data["NM_EMAIL"]= "-"
data.drop(["CODIGO_MUNICIPIO"],1)


data.reindex(columns=["DATA_GERACAO",
"HORA_GERACAO",
"ANO_ELEICAO",
"NUM_TURNO",
"DESCRICAO_ELEICAO",
"SIGLA_UF",
"SIGLA_UE",
"DESCRICAO_UE",
"CODIGO_CARGO",
"DESCRICAO_CARGO",
"NOME_CANDIDATO",
"SEQUENCIAL_CANDIDATO",
"NUMERO_CANDIDATO",
"CPF_CANDIDATO",
"NOME_URNA_CANDIDATO",
"COD_SITUACAO_CANDIDATURA",
"DES_SITUACAO_CANDIDATURA",
"NUMERO_PARTIDO",
"SIGLA_PARTIDO",
"NOME_PARTIDO",
"CODIGO_LEGENDA",
"SIGLA_LEGENDA",
"COMPOSICAO_LEGENDA",
"NOME_LEGENDA",
"CODIGO_OCUPACAO",
"DESCRICAO_OCUPACAO",
"DATA_NASCIMENTO",
"NUM_TITULO_ELEITORAL_CANDIDATO",
"IDADE_DATA_ELEICAO",
"CODIGO_SEXO",
"DESCRICAO_SEXO",
"COD_GRAU_INSTRUCAO",
"DESCRICAO_GRAU_INSTRUCAO",
"CODIGO_ESTADO_CIVIL",
"DESCRICAO_ESTADO_CIVIL",
"CODIGO_COR_RACA",
"DESCRICAO_COR_RACA",
"CODIGO_NACIONALIDADE",
"DESCRICAO_NACIONALIDADE",
"SIGLA_UF_NASCIMENTO",
"CODIGO_MUNICIPIO_NASCIMENTO",
"NOME_MUNICIPIO_NASCIMENTO",
"DESPESA_MAX_CAMPANHA",
"COD_SIT_TOT_TURNO",
"DESC_SIT_TOT_TURNO",
"NM_EMAIL"]).to_csv('output/nulos.txt',sep=';', encoding='utf-8',index=False,header=False, quoting=csv.QUOTE_ALL)

# %%
columns=["DATA_GERACAO",
"HORA_GERACAO",
"ANO_ELEICAO",
"NUM_TURNO",
"DESCRICAO_ELEICAO",
"SIGLA_UF",
"SIGLA_UE",
"DESCRICAO_UE",
"CODIGO_CARGO",
"DESCRICAO_CARGO",
"NOME_CANDIDATO",
"SEQUENCIAL_CANDIDATO",
"NUMERO_CANDIDATO",
"CPF_CANDIDATO",
"NOME_URNA_CANDIDATO",
"COD_SITUACAO_CANDIDATURA",
"DES_SITUACAO_CANDIDATURA",
"NUMERO_PARTIDO",
"SIGLA_PARTIDO",
"NOME_PARTIDO",
"CODIGO_LEGENDA",
"SIGLA_LEGENDA",
"COMPOSICAO_LEGENDA",
"NOME_LEGENDA",
"CODIGO_OCUPACAO",
"DESCRICAO_OCUPACAO",
"DATA_NASCIMENTO",
"NUM_TITULO_ELEITORAL_CANDIDATO",
"IDADE_DATA_ELEICAO",
"CODIGO_SEXO",
"DESCRICAO_SEXO",
"COD_GRAU_INSTRUCAO",
"DESCRICAO_GRAU_INSTRUCAO",
"CODIGO_ESTADO_CIVIL",
"DESCRICAO_ESTADO_CIVIL",
"CODIGO_COR_RACA",
"DESCRICAO_COR_RACA",
"CODIGO_NACIONALIDADE",
"DESCRICAO_NACIONALIDADE",
"SIGLA_UF_NASCIMENTO",
"CODIGO_MUNICIPIO_NASCIMENTO",
"NOME_MUNICIPIO_NASCIMENTO",
"DESPESA_MAX_CAMPANHA",
"COD_SIT_TOT_TURNO",
"DESC_SIT_TOT_TURNO",
"NM_EMAIL"]

data = pd.read_csv("output/nulos.txt",delimiter=";",error_bad_lines=False,names=columns)

# %%
d = data[data["SIGLA_UF"]=="ZZ"]
d[["SIGLA_UF","SIGLA_UE","DESCRICAO_UE","CODIGO_CARGO"]]
# Out:
#     SIGLA_UF SIGLA_UE DESCRICAO_UE  CODIGO_CARGO
# 95        ZZ       ZZ   PRESIDENTE            96
# 158       ZZ       ZZ   PRESIDENTE            96

# %%
import pandas as pd
import csv
presidentes = pd.read_csv("input/brancos_presidente.csv",delimiter="\t",error_bad_lines=False,names=["ANO_ELEICAO","NUM_TURNO","DESCRICAO_ELEICAO","SIGLA_UF","SIGLA_UE","CODIGO_CARGO","DESCRICAO_CARGO","NUMERO_CANDIDATO"])
presidentes["SIGLA_UE"] = "BR"

presidentes["DATA_GERACAO"]= ""
presidentes["HORA_GERACAO"]= ""
presidentes["NOME_CANDIDATO"]= "Voto Branco"
presidentes["SEQUENCIAL_CANDIDATO"]= "#BRANCO#"
presidentes["CPF_CANDIDATO"]= "#BRANCO#"
presidentes["NOME_URNA_CANDIDATO"]= "Voto Branco"
presidentes["COD_SITUACAO_CANDIDATURA"]= "-1"
presidentes["DES_SITUACAO_CANDIDATURA"]= "-"
presidentes["NUMERO_PARTIDO"]= "95"
presidentes["SIGLA_PARTIDO"]= "#BRANCO#"
presidentes["NOME_PARTIDO"]= "#BRANCO#"
presidentes["CODIGO_LEGENDA"]= "#BRANCO#"
presidentes["DESCRICAO_UE"]= presidentes["SIGLA_UE"]
presidentes["SIGLA_LEGENDA"]= "#BRANCO#"
presidentes["COMPOSICAO_LEGENDA"]= "#BRANCO#"
presidentes["NOME_LEGENDA"]= "#BRANCO#"
presidentes["CODIGO_OCUPACAO"]= "-1"
presidentes["DESCRICAO_OCUPACAO"]= "#BRANCO#"
presidentes["DATA_NASCIMENTO"]= ""
presidentes["NUM_TITULO_ELEITORAL_CANDIDATO"]= "#BRANCO#"
presidentes["IDADE_DATA_ELEICAO"]= "-1"
presidentes["CODIGO_SEXO"]= "-1"
presidentes["DESCRICAO_SEXO"]= "-"
presidentes["COD_GRAU_INSTRUCAO"]= "-1"
presidentes["DESCRICAO_GRAU_INSTRUCAO"]= "-"
presidentes["CODIGO_ESTADO_CIVIL"]= "-1"
presidentes["DESCRICAO_ESTADO_CIVIL"]= "-"
presidentes["CODIGO_COR_RACA"]= "-1"
presidentes["DESCRICAO_COR_RACA"]= "-"
presidentes["CODIGO_NACIONALIDADE"]= "-1"
presidentes["DESCRICAO_NACIONALIDADE"]= "-"
presidentes["SIGLA_UF_NASCIMENTO"]= "-"
presidentes["CODIGO_MUNICIPIO_NASCIMENTO"]= "-"
presidentes["NOME_MUNICIPIO_NASCIMENTO"]= "-"
presidentes["DESPESA_MAX_CAMPANHA"]= "-"
presidentes["COD_SIT_TOT_TURNO"]= "-"
presidentes["DESC_SIT_TOT_TURNO"]= "-"
presidentes["NM_EMAIL"]= "-"

presidentes.reindex(columns=["DATA_GERACAO",
"HORA_GERACAO",
"ANO_ELEICAO",
"NUM_TURNO",
"DESCRICAO_ELEICAO",
"SIGLA_UF",
"SIGLA_UE",
"DESCRICAO_UE",
"CODIGO_CARGO",
"DESCRICAO_CARGO",
"NOME_CANDIDATO",
"SEQUENCIAL_CANDIDATO",
"NUMERO_CANDIDATO",
"CPF_CANDIDATO",
"NOME_URNA_CANDIDATO",
"COD_SITUACAO_CANDIDATURA",
"DES_SITUACAO_CANDIDATURA",
"NUMERO_PARTIDO",
"SIGLA_PARTIDO",
"NOME_PARTIDO",
"CODIGO_LEGENDA",
"SIGLA_LEGENDA",
"COMPOSICAO_LEGENDA",
"NOME_LEGENDA",
"CODIGO_OCUPACAO",
"DESCRICAO_OCUPACAO",
"DATA_NASCIMENTO",
"NUM_TITULO_ELEITORAL_CANDIDATO",
"IDADE_DATA_ELEICAO",
"CODIGO_SEXO",
"DESCRICAO_SEXO",
"COD_GRAU_INSTRUCAO",
"DESCRICAO_GRAU_INSTRUCAO",
"CODIGO_ESTADO_CIVIL",
"DESCRICAO_ESTADO_CIVIL",
"CODIGO_COR_RACA",
"DESCRICAO_COR_RACA",
"CODIGO_NACIONALIDADE",
"DESCRICAO_NACIONALIDADE",
"SIGLA_UF_NASCIMENTO",
"CODIGO_MUNICIPIO_NASCIMENTO",
"NOME_MUNICIPIO_NASCIMENTO",
"DESPESA_MAX_CAMPANHA",
"COD_SIT_TOT_TURNO",
"DESC_SIT_TOT_TURNO",
"NM_EMAIL"]).to_csv('output/brancos_presidente.txt',sep=';', encoding='utf-8',index=False,header=False, quoting=csv.QUOTE_ALL)

# %%
presidentes = pd.read_csv("input/nulos_presidente.csv",delimiter="\t",error_bad_lines=False,names=["ANO_ELEICAO","NUM_TURNO","DESCRICAO_ELEICAO","SIGLA_UF","SIGLA_UE","CODIGO_CARGO","DESCRICAO_CARGO","NUMERO_CANDIDATO"])
presidentes["SIGLA_UE"] = "BR"

presidentes["DATA_GERACAO"]= ""
presidentes["HORA_GERACAO"]= ""
presidentes["NOME_CANDIDATO"]= "Voto Branco"
presidentes["SEQUENCIAL_CANDIDATO"]= "#BRANCO#"
presidentes["CPF_CANDIDATO"]= "#BRANCO#"
presidentes["NOME_URNA_CANDIDATO"]= "Voto Branco"
presidentes["COD_SITUACAO_CANDIDATURA"]= "-1"
presidentes["DES_SITUACAO_CANDIDATURA"]= "-"
presidentes["NUMERO_PARTIDO"]= "95"
presidentes["SIGLA_PARTIDO"]= "#BRANCO#"
presidentes["NOME_PARTIDO"]= "#BRANCO#"
presidentes["CODIGO_LEGENDA"]= "#BRANCO#"
presidentes["DESCRICAO_UE"]= presidentes["SIGLA_UE"]
presidentes["SIGLA_LEGENDA"]= "#BRANCO#"
presidentes["COMPOSICAO_LEGENDA"]= "#BRANCO#"
presidentes["NOME_LEGENDA"]= "#BRANCO#"
presidentes["CODIGO_OCUPACAO"]= "-1"
presidentes["DESCRICAO_OCUPACAO"]= "#BRANCO#"
presidentes["DATA_NASCIMENTO"]= ""
presidentes["NUM_TITULO_ELEITORAL_CANDIDATO"]= "#BRANCO#"
presidentes["IDADE_DATA_ELEICAO"]= "-1"
presidentes["CODIGO_SEXO"]= "-1"
presidentes["DESCRICAO_SEXO"]= "-"
presidentes["COD_GRAU_INSTRUCAO"]= "-1"
presidentes["DESCRICAO_GRAU_INSTRUCAO"]= "-"
presidentes["CODIGO_ESTADO_CIVIL"]= "-1"
presidentes["DESCRICAO_ESTADO_CIVIL"]= "-"
presidentes["CODIGO_COR_RACA"]= "-1"
presidentes["DESCRICAO_COR_RACA"]= "-"
presidentes["CODIGO_NACIONALIDADE"]= "-1"
presidentes["DESCRICAO_NACIONALIDADE"]= "-"
presidentes["SIGLA_UF_NASCIMENTO"]= "-"
presidentes["CODIGO_MUNICIPIO_NASCIMENTO"]= "-"
presidentes["NOME_MUNICIPIO_NASCIMENTO"]= "-"
presidentes["DESPESA_MAX_CAMPANHA"]= "-"
presidentes["COD_SIT_TOT_TURNO"]= "-"
presidentes["DESC_SIT_TOT_TURNO"]= "-"
presidentes["NM_EMAIL"]= "-"

presidentes.reindex(columns=["DATA_GERACAO",
"HORA_GERACAO",
"ANO_ELEICAO",
"NUM_TURNO",
"DESCRICAO_ELEICAO",
"SIGLA_UF",
"SIGLA_UE",
"DESCRICAO_UE",
"CODIGO_CARGO",
"DESCRICAO_CARGO",
"NOME_CANDIDATO",
"SEQUENCIAL_CANDIDATO",
"NUMERO_CANDIDATO",
"CPF_CANDIDATO",
"NOME_URNA_CANDIDATO",
"COD_SITUACAO_CANDIDATURA",
"DES_SITUACAO_CANDIDATURA",
"NUMERO_PARTIDO",
"SIGLA_PARTIDO",
"NOME_PARTIDO",
"CODIGO_LEGENDA",
"SIGLA_LEGENDA",
"COMPOSICAO_LEGENDA",
"NOME_LEGENDA",
"CODIGO_OCUPACAO",
"DESCRICAO_OCUPACAO",
"DATA_NASCIMENTO",
"NUM_TITULO_ELEITORAL_CANDIDATO",
"IDADE_DATA_ELEICAO",
"CODIGO_SEXO",
"DESCRICAO_SEXO",
"COD_GRAU_INSTRUCAO",
"DESCRICAO_GRAU_INSTRUCAO",
"CODIGO_ESTADO_CIVIL",
"DESCRICAO_ESTADO_CIVIL",
"CODIGO_COR_RACA",
"DESCRICAO_COR_RACA",
"CODIGO_NACIONALIDADE",
"DESCRICAO_NACIONALIDADE",
"SIGLA_UF_NASCIMENTO",
"CODIGO_MUNICIPIO_NASCIMENTO",
"NOME_MUNICIPIO_NASCIMENTO",
"DESPESA_MAX_CAMPANHA",
"COD_SIT_TOT_TURNO",
"DESC_SIT_TOT_TURNO",
"NM_EMAIL"]).to_csv('output/nulos_presidente.txt',sep=';', encoding='utf-8',index=False,header=False, quoting=csv.QUOTE_ALL)
